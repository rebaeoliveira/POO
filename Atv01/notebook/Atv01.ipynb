// %% [markdown]
// # Atv01

// %% [markdown]
// Apresente a soma de todos os argumentos inteiros ou reais recebidos

// %%
import java.util.Scanner;
double a, b, c, d, e, soma = 0;
        Scanner s = new Scanner(System.in);
        System.out.println("Digite números inteiros ou reais: ");
        a = s.nextDouble();
        b = s.nextDouble();
        c = s.nextDouble();
        d = s.nextDouble();
        e = s.nextDouble();
        soma = a + b + c + d + e;
        System.out.println("A soma dos números é: " + soma);
// Out:
// Digite números inteiros ou reais:
//  47.98
//  45.78
//  98
//  30
//  89.25
// A soma dos números é: 311.01
// null
